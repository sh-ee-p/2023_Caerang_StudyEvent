# %% [markdown]
# ## BOJ 1085
#
# - x, y, w-x, h-y 중에서 최솟값을 출력하면 되는 문제
# -------------
# ## BOJ 1247
#
# - 시간이 너무 오래 걸릴 경우 import sys를 사용해서 input() 대신 sys.stdin.readline()을 사용한다.
# - 입력을 빠르게 받아올 수 있다.
# - 개행문자를 제외하고 받고 싶을 경우에는 끝에 strip()을 쓴다
# - 외에도 rstrip(), lstrip()이 있는데 각각 공백 제거, 동일 문자 제거 역할을 한다.
# ---------
# ## BOJ 11654
#
# - 아스키코드를 활용 가능한 함수는 ord()와 chr()이 있다.
#     - ord() : 문자 -> 아스키코드
#     - chr() : 아스키코드 -> 문자
# - 대문자 알파벳 아스키코드<소문자 알파벳 아스키코드
# - 알파벳 순서대로 아스키코드도 1씩 증가한다.
# ------------
# ## BOJ 2744
#
# - 대소문자로 바꾸는 함수
#     - .upper() : 문자열을 대문자로 변환
#     - .lower() : 문자열을 소문자로 변환
#     - .isupper() : 문자열이 대문자로 이루어져있는지 확인(반환값 boolean 타입)
#     - .islower() : 문자열이 소문자로 이루어져있는지 확인(반환값 boolean 타입)
# -------
# ## BOJ 1157
#
# - set로 만든 뒤에 list로 만들면 중복된 값이 없는 list 생성 가능
# ---------
# ## BOJ 2231
#
# - 분해합과 생성자의 관계를 잘 생각해보기
# ------------
# ## BOJ 2609
#
# - 최대공약수 : GCD
# - 최소공배수 : LCM
# --------------
# ## BOJ 1436
#
# - 브루트 포스 탐색
#     - 가능한 모든 경우의 수를 탐색하여 조건에 알맞는 결과를 가져옴
#     - 예외없이 100% 확률로 정답을 출력함
#     - 깊이 우선 탐색(DFS, Depth First Search), 너비 우선 탐색(BFS, Breadth First Search)
# /n
# - 너비 우선 탐색(DFS, Depth First Searching)
#     - 탐색트리의 루트노드부터 목표노드를 만날 때까지 단계별로 횡방향으로 탐색 진행
#     - 출발노드에서 목표노드까지의 최단 길이 경로를 보장함
#     - 많은 기억 공간을 필요로 하거나 해가 존재하지 않을 경우 실패하거나 무한 그래프일 경우 해를 찾지 못하고 끝내지도 못하는 경우도 발생 가능
# ---------------
# ## BOJ 2869
#
# - import math로 math 모듈을 통해 math.ceil()로 실수를 올림처리함
# ------------
# ## BOJ 1009
#
# - 끝자리수만 결과에 영향을 주기 때문에 끝자리수의 규칙을 찾고 그에 따라 조건식을 써줄 것
